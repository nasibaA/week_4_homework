# %%
import pandas as pd




# Create a dataframe to demonstrate grouping

raw_dict = {"Vehicle Type": ["Car", "Car", "SUV", "Car", "Truck", "Truck", "SUV", "Truck", "Car", "SUV", "SUV", "Truck"],
            "Manufacturer": ["Ford", "GM", "Ford", "Chevy", "Ford", "Chevy", "GM", "GM", "Ford", "Chevy", "GM", "Chevy"],
            "Owner": ["Bob", "Andrew", "Sally", "Amanda", "Bill", "Mike", "Lindsey", "Kristen", "Matt", "Anna", "Jon", "Erin"],
            "Horsepower": [265, 190, 240, 350, 365, 400, 275, 300, 185, 280, 310, 240],
            "Torque (lb-ft)": [270, 215, 203, 350, 415, 275, 290, 190, 280, 305, 250, 290],
            "Fuel Economy (mpg)": [25, 27, 22, 31, 19, 17, 23, 18, 27, 21, 19, 18]}
vehicles_df = pd.DataFrame(raw_dict)
vehicles_df
# Out:
#    Vehicle Type Manufacturer    Owner  Horsepower  Torque (lb-ft)  \
# 0           Car         Ford      Bob         265             270
# 1           Car           GM   Andrew         190             215
# 2           SUV         Ford    Sally         240             203
# 3           Car        Chevy   Amanda         350             350
# 4         Truck         Ford     Bill         365             415
# 5         Truck        Chevy     Mike         400             275
# 6           SUV           GM  Lindsey         275             290
# 7         Truck           GM  Kristen         300             190
# 8           Car         Ford     Matt         185             280
# 9           SUV        Chevy     Anna         280             305
# 10          SUV           GM      Jon         310             250
# 11        Truck        Chevy     Erin         240             290
#
#     Fuel Economy (mpg)
# 0                   25
# 1                   27
# 2                   22
# 3                   31
# 4                   19
# 5                   17
# 6                   23
# 7                   18
# 8                   27
# 9                   21
# 10                  19
# 11                  18

# %%
grouped_vehicles_df = vehicles_df.groupby("Vehicle Type")
print(grouped_vehicles_df)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0AE773A0>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17176/984873048.py in <module>
#       1 grouped_vehicles_df = vehicles_df.groupby("Vehicle Type")
#       2 print(grouped_vehicles_df)
# ----> 3 grouped_vehicles_df["Fuel Economy(mpg)"].mean()
#
# c:\users\12674\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\users\12674\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: Fuel Economy(mpg)'

# %%
grouped_vehicles_df.count()
# Out:
#               Manufacturer  Owner  Horsepower  Torque (lb-ft)  \
# Vehicle Type
# Car                      4      4           4               4
# SUV                      4      4           4               4
# Truck                    4      4           4               4
#
#               Fuel Economy (mpg)
# Vehicle Type
# Car                            4
# SUV                            4
# Truck                          4

# %%
grouped_vehicles_df["Fuel Economy(mpg)"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17176/3201651289.py in <module>
# ----> 1 grouped_vehicles_df["Fuel Economy(mpg)"].mean()
#
# c:\users\12674\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\users\12674\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: Fuel Economy(mpg)'
